# %% [markdown]
# ## Capstone Project - Where do folks in Indiranagar, Bangalore like to hang out?

# %%
# Importing necessary python modules
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
#import random # library for random number generation

#!conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# %% [markdown]
# Define Foursquare Details

# %%
CLIENT_ID = 'QS2CU0N3U4P3GJIYJAZFNOXVSL4HDYVFMJNTYM4FGOFNVQO2' # your Foursquare ID
CLIENT_SECRET = '45PPL2FIQ1QAAA5Y2BTDFKP210P1UNE5HO1RVSJVZIHU2TRN' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: QS2CU0N3U4P3GJIYJAZFNOXVSL4HDYVFMJNTYM4FGOFNVQO2
# CLIENT_SECRET:45PPL2FIQ1QAAA5Y2BTDFKP210P1UNE5HO1RVSJVZIHU2TRN

# %% [markdown]
# Since, I live in Bangalore I know that Indiranagar is one of the hot spots to hang out. So let us fetch the latitude and longitude of Indiranagar so that we can get the venues around it.

# %%
address = 'Indiranagar, Bangalore'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 12.9732913 77.6404672

# %% [markdown]
# Now let us fetch all venues within 2000 mts of Indranagar

# %%
search_query = 'Hotel Bar'
radius = 2000
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=QS2CU0N3U4P3GJIYJAZFNOXVSL4HDYVFMJNTYM4FGOFNVQO2&client_secret=45PPL2FIQ1QAAA5Y2BTDFKP210P1UNE5HO1RVSJVZIHU2TRN&ll=12.9732913,77.6404672&v=20180604&query=Hotel Bar&radius=2000&limit=30'

# %% [markdown]
# Let us use the above url to get the list of venues around Indranagar

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d6ea1aebe7078002c48ef3f'},
#  'response': {'venues': [{'id': '4b8e74edf964a520942333e3',
#     'name': 'Hotel Shalimar Bar and Restaurant',
#     'location': {'address': '322/1 CMH Road',
#      'crossStreet': 'Indiranagar',
#      'lat': 12.978253448591232,
#      'lng': 77.63736833055371,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.978253448591232,
#        'lng': 77.63736833055371}],
#      'distance': 646,
#      'postalCode': '560038',
#      'cc': 'IN',
#      'city': 'Bangalore',
#      'state': 'Karnātaka',
#      'country': 'India',
#      'formattedAddress': ['322/1 CMH Road (Indiranagar)',
#       'Bangalore 560038',
#       'Karnātaka',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1567531438',
#     'hasPerk': False},
#    {'id': '4b685a68f964a5205a732be3',
#     'name': 'Xtreme Sports Bar',
#     'location': {'address': '100 Feet Rd',
#      'crossStreet': 'Indiranagar',
#      'lat': 12.970794875650837,
#      'lng': 77.641164363067,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.970794875650837,
#        'lng': 77.641164363067}],
#      'distance': 288,
#      'cc': 'IN',
#      'city': 'Bangalore',
#      'state': 'Karnātaka',
#      'country': 'India',
#      'formattedAddress': ['100 Feet Rd (Indiranagar)',
#       'Bangalore',
#       'Karnātaka',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d11d941735',
#       'name': 'Sports Bar',
#       'pluralName': 'Sports Bars',
#       'shortName': 'Sports Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/sportsbar_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1567531438',
#     'hasPerk': False},
#    {'id': '4eea06f3b634ea5579ee83a3',
#     'name': 'Escape Hotel & Spa',
#     'location': {'address': '#700 100 Feet Rd',
#      'lat': 12.969983177464986,
#      'lng': 77.64114575299904,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.969983177464986,
#        'lng': 77.64114575299904}],
#      'distance': 375,
#      'postalCode': '560038',
#      'cc': 'IN',
#      'city': 'Bangalore',
#      'state': 'Karnātaka',
#      'country': 'India',
#      'formattedAddress': ['#700 100 Feet Rd',
#       'Bangalore 560038',
#       'Karnātaka',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1567531438',
#     'hasPerk': False},
#    {'id': '5340596b498e3c13ad5f59a7',
#     'name': 'Monkey Bar',
#     'location': {'address': '610, Diagonally Opposite SBI Bank, Near Apple of My I, Indiranagar',
#      'crossStreet': '12th Main',
#      'lat': 12.970328689143555,
#      'lng': 77.64510698235551,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.970328689143555,
#        'lng': 77.64510698235551}],
#      'distance': 601,
#      'cc': 'IN',
#      'city': 'Bangalore',
#      'state': 'Karnātaka',
#      'country': 'India',
#      'formattedAddress': ['610, Diagonally Opposite SBI Bank, Near Apple of My I, Indiranagar (12th Main)',
#       'Bangalore',
#       'Karnātaka',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1567531438',
#     'hasPerk': False},
#    {'id': '4ba46d04f964a520999c38e3',
#     'name': 'Hotel Royal Orchid',
#     'location': {'address': '#1, Golf Avenue',
#      'crossStreet': 'HAL Airport Road',
#      'lat': 12.957208484767675,
#      'lng': 77.64422244043912,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.957208484767675,
#        'lng': 77.64422244043912}],
#      'distance': 1836,
#      'postalCode': '560008',
#      'cc': 'IN',
#      'city': 'Bangalore',
#      'state': 'Karnātaka',
#      'country': 'India',
#      'formattedAddress': ['#1, Golf Avenue (HAL Airport Road)',
#       'Bangalore 560008',
#       'Karnātaka',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1567531438',
#     'hasPerk': False},
#    {'id': '4e0985d8483b98d4171d993c',
#     'name': 'J K Military Hotel',
#     'location': {'address': '7th Main Rd, Indira Nagar III Stage',
#      'crossStreet': 'Indira Nagar',
#      'lat': 12.972616441453063,
#      'lng': 77.63811080568914,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.972616441453063,
#        'lng': 77.63811080568914}],
#      'distance': 266,
#      'cc': 'IN',
#      'city': 'Bangalore',
#      'state': 'Karnātaka',
#      'country': 'India',
#      'formattedAddress': ['7th Main Rd, Indira Nagar III Stage (Indira Nagar)',
#       'Bangalore',
#       'Karnātaka',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1567531438',
#     'hasPerk': False},
#    {'id': '5cdace71b399f7002c75331a',
#     'name': 'Buddys - Bar & Cafe',
#     'location': {'address': '654, 1st floor',
#      'crossStreet': 'Navjyothi building 10th A Main, 100 Feet Rd, Indir',
#      'lat': 12.973571149775557,
#      'lng': 77.64143228530884,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.973571149775557,
#        'lng': 77.64143228530884}],
#      'distance': 109,
#      'postalCode': '560038',
#      'cc': 'IN',
#      'city': 'Bangalore',
#      'state': 'Karnātaka',
#      'country': 'India',
#      'formattedAddress': ['654, 1st floor (Navjyothi building 10th A Main, 100 Feet Rd, Indir)',
#       'Bangalore 560038',
#       'Karnātaka',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1567531438',
#     'hasPerk': False},
#    {'id': '55f317ca498ebbeb5a53d7ab',
#     'name': 'Tippler On the Roof',
#     'location': {'address': '276, 100 Ft. Rd',
#      'lat': 12.974306049948654,
#      'lng': 77.64098805291313,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.974306049948654,
#        'lng': 77.64098805291313}],
#      'distance': 126,
#      'cc': 'IN',
#      'city': 'Bangalore',
#      'state': 'Karnātaka',
#      'country': 'India',
#      'formattedAddress': ['276, 100 Ft. Rd',
#       'Bangalore',
#       'Karnātaka',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d121941735',
#       'name': 'Lounge',
#       'pluralName': 'Lounges',
#       'shortName': 'Lounge',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1567531438',
#     'hasPerk': False},
#    {'id': '5a0477da31ac6c284a78a5b9',
#     'name': '1131 Bar N Kitchen',
#     'location': {'address': '100 feet road, Indiranagar',
#      'lat': 12.969915566801303,
#      'lng': 77.64134445399704,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.969915566801303,
#        'lng': 77.64134445399704}],
#      'distance': 387,
#      'postalCode': '560038',
#      'cc': 'IN',
#      'city': 'Bangalore',
#      'state': 'Karnātaka',
#      'country': 'India',
#      'formattedAddress': ['100 feet road, Indiranagar',
#       'Bangalore 560038',
#       'Karnātaka',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d11e941735',
#       'name': 'Cocktail Bar',
#       'pluralName': 'Cocktail Bars',
#       'shortName': 'Cocktail',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1567531438',
#     'hasPerk': False},
#    {'id': '4c62b2dffa7bc928f5ab0e27',
#     'name': 'Retro Lounge Bar',
#     'location': {'address': '18/1, Cambridge Rd,',
#      'crossStreet': 'Ulsoor',
#      'lat': 12.972614445679424,
#      'lng': 77.6267001093147,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.972614445679424,
#        'lng': 77.6267001093147}],
#      'distance': 1495,
#      'cc': 'IN',
#      'city': 'Bangalore',
#      'state': 'Karnātaka',
#      'country': 'India',
#      'formattedAddress': ['18/1, Cambridge Rd, (Ulsoor)',
#       'Bangalore',
#       'Karnātaka',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1567531438',
#     'hasPerk': False},
#    {'id': '55311431498edd664401629e',
#     'name': 'Chianti Ristorante & Wine Bar',
#     'location': {'address': '12 Main, Indiranagar',
#      'lat': 12.970166816699923,
#      'lng': 77.6403456189779,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.970166816699923,
#        'lng': 77.6403456189779}],
#      'distance': 348,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['12 Main, Indiranagar', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1567531438',
#     'hasPerk': False},
#    {'id': '51a61c6e498ec6f690bf2987',
#     'name': 'The Humming Tree - Music Venue and Bar',
#     'location': {'address': '949, 12th Main Rd. (3rd Floor and Roof) Landmark: Next to ICICI Bank',
#      'crossStreet': 'Indira Nagar',
#      'lat': 12.970124587896086,
#      'lng': 77.639161198021,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.970124587896086,
#        'lng': 77.639161198021}],
#      'distance': 379,
#      'postalCode': '560038',
#      'cc': 'IN',
#      'city': 'Bangalore',
#      'state': 'Karnātaka',
#      'country': 'India',
#      'formattedAddress': ['949, 12th Main Rd. (3rd Floor and Roof) Landmark: Next to ICICI Bank (Indira Nagar)',
#       'Bangalore 560038',
#       'Karnātaka',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d1e5931735',
#       'name': 'Music Venue',
#       'pluralName': 'Music Venues',
#       'shortName': 'Music Venue',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '57953622'},
#     'referralId': 'v-1567531438',
#     'hasPerk': False},
#    {'id': '5bcf3d0a31fd14002c6dba07',
#     'name': "Bob's Bar",
#     'location': {'lat': 12.967081570328242,
#      'lng': 77.64139470111513,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.967081570328242,
#        'lng': 77.64139470111513}],
#      'distance': 698,
#      'postalCode': '560038',
#      'cc': 'IN',
#      'city': 'Bangalore',
#      'state': 'Karnātaka',
#      'country': 'India',
#      'formattedAddress': ['Bangalore 560038', 'Karnātaka', 'India']},
#     'categories': [{'id': '54135bf5e4b08f3d2429dfeb',
#       'name': 'Karnataka Restaurant',
#       'pluralName': 'Karnataka Restaurants',
#       'shortName': 'Karnataka',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1567531438',
#     'hasPerk': False},
#    {'id': '4e0a20ed14959022c8a93dec',
#     'name': 'Library Bar',
#     'location': {'address': '#23, The Leela Palace',
#      'crossStreet': 'Old Airport Rd',
#      'lat': 12.961287933488943,
#      'lng': 77.648628628446,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.961287933488943,
#        'lng': 77.648628628446}],
#      'distance': 1602,
#      'postalCode': '560017',
#      'cc': 'IN',
#      'city': 'Bangalore',
#      'state': 'Karnātaka',
#      'country': 'India',
#      'formattedAddress': ['#23, The Leela Palace (Old Airport Rd)',
#       'Bangalore 560017',
#       'Karnātaka',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1567531438',
#     'hasPerk': False},
#    {'id': '4e02e6c6a809d5cf4526a843',
#     'name': 'ಗೌಡ್ರು ಮಿಲಿಟರಿ ಹೋಟೆಲ್ (Gowdru Military Hotel)',
#     'location': {'address': 'Indira Nagar Double Rd, Indira Nagar',
#      'lat': 12.974109913917701,
#      'lng': 77.63590130416488,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.974109913917701,
#        'lng': 77.63590130416488}],
#      'distance': 503,
#      'cc': 'IN',
#      'city': 'Bangalore',
#      'state': 'Karnātaka',
#      'country': 'India',
#      'formattedAddress': ['Indira Nagar Double Rd, Indira Nagar',
#       'Bangalore',
#       'Karnātaka',
#       'India']},
#     'categories': [{'id': '54135bf5e4b08f3d2429dfeb',
#       'name': 'Karnataka Restaurant',
#       'pluralName': 'Karnataka Restaurants',
#       'shortName': 'Karnataka',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1567531438',
#     'hasPerk': False},
#    {'id': '533850ad498e5cc1a990f184',
#     'name': 'Monkey Bar',
#     'location': {'address': '#610, 12th Main Rd',
#      'lat': 12.97039919840766,
#      'lng': 77.64527105931315,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.97039919840766,
#        'lng': 77.64527105931315}],
#      'distance': 612,
#      'postalCode': '560038',
#      'cc': 'IN',
#      'neighborhood': 'HAL 2nd stage',
#      'city': 'Bangalore',
#      'state': 'Karnātaka',
#      'country': 'India',
#      'formattedAddress': ['#610, 12th Main Rd',
#       'Bangalore 560038',
#       'Karnātaka',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'shortName': 'Pub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1567531438',
#     'hasPerk': False},
#    {'id': '4bbb52c3cf2fc9b60f6da202',
#     'name': 'High Note Bar and Dining',
#     'location': {'address': '776, 100 ft. Road',
#      'crossStreet': 'Opp. Little Italy, Indiranagar',
#      'lat': 12.968883137056034,
#      'lng': 77.64116267019021,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.968883137056034,
#        'lng': 77.64116267019021}],
#      'distance': 496,
#      'postalCode': '560038',
#      'cc': 'IN',
#      'city': 'Bangalore',
#      'state': 'Karnātaka',
#      'country': 'India',
#      'formattedAddress': ['776, 100 ft. Road (Opp. Little Italy, Indiranagar)',
#       'Bangalore 560038',
#       'Karnātaka',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d147941735',
#       'name': 'Diner',
#       'pluralName': 'Diners',
#       'shortName': 'Diner',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1567531438',
#     'hasPerk': False},
#    {'id': '4b7028aef964a5205f092de3',
#     'name': 'Suri Bar And Restaurant',
#     'location': {'address': 'Old Airport Road, Kodihalli',
#      'crossStreet': '2nd Cross',
#      'lat': 12.960564828571146,
#      'lng': 77.6439642906189,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.960564828571146,
#        'lng': 77.6439642906189}],
#      'distance': 1466,
#      'postalCode': '560008',
#      'cc': 'IN',
#      'city': 'Bangalore',
#      'state': 'Karnātaka',
#      'country': 'India',
#      'formattedAddress': ['Old Airport Road, Kodihalli (2nd Cross)',
#       'Bangalore 560008',
#       'Karnātaka',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1567531438',
#     'hasPerk': False},
#    {'id': '4f539056e4b03be36423185e',
#     'name': 'Hotel Hyper City',
#     'location': {'address': '18th main road',
#      'lat': 12.964010701992933,
#      'lng': 77.64620448172919,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.964010701992933,
#        'lng': 77.64620448172919}],
#      'distance': 1206,
#      'postalCode': '560008',
#      'cc': 'IN',
#      'city': 'Hal 2nd stage , Indiranagar',
#      'country': 'India',
#      'formattedAddress': ['18th main road',
#       'Hal 2nd stage , Indiranagar 560008',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1567531438',
#     'hasPerk': False},
#    {'id': '50ba05f6e4b013672743c917',
#     'name': 'Lakeview Milk Bar',
#     'location': {'address': 'Lakeview Milkbar Indiranagar, Bangalore, India address 776, 100 Feet Road, Near ING Vysa Bank, Indiranagar, Bangalore',
#      'crossStreet': 'Indiranagar',
#      'lat': 12.96900125775404,
#      'lng': 77.64133918178814,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.96900125775404,
#        'lng': 77.64133918178814}],
#      'distance': 486,
#      'cc': 'IN',
#      'city': 'Bangalore',
#      'state': 'Karnātaka',
#      'country': 'India',
#      'formattedAddress': ['Lakeview Milkbar Indiranagar, Bangalore, India address 776, 100 Feet Road, Near ING Vysa Bank, Indiranagar, Bangalore (Indiranagar)',
#       'Bangalore',
#       'Karnātaka',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1567531438',
#     'hasPerk': False},
#    {'id': '51ceb927498e9830f7d20a93',
#     'name': 'The Paramount hotel',
#     'location': {'address': 'Indira Nagar',
#      'crossStreet': '100ft road',
#      'lat': 12.97148736014721,
#      'lng': 77.64122640866289,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.97148736014721,
#        'lng': 77.64122640866289}],
#      'distance': 217,
#      'cc': 'IN',
#      'city': 'Bangalore',
#      'state': 'Karnātaka',
#      'country': 'India',
#      'formattedAddress': ['Indira Nagar (100ft road)',
#       'Bangalore',
#       'Karnātaka',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1567531438',
#     'hasPerk': False},
#    {'id': '55979d94498ef8cc2442fee2',
#     'name': 'BAREBONES The Balcony Bar',
#     'location': {'address': '100 Ft Rd, Indiranagar',
#      'lat': 12.980065854525533,
#      'lng': 77.64071887292855,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.980065854525533,
#        'lng': 77.64071887292855}],
#      'distance': 754,
#      'cc': 'IN',
#      'city': 'Bangalore',
#      'state': 'Karnātaka',
#      'country': 'India',
#      'formattedAddress': ['100 Ft Rd, Indiranagar',
#       'Bangalore',
#       'Karnātaka',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'shortName': 'Pub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1567531438',
#     'hasPerk': False},
#    {'id': '4f8ed510e4b0e25286acac8f',
#     'name': 'Hotel Capital',
#     'location': {'lat': 12.984408,
#      'lng': 77.633528,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.984408,
#        'lng': 77.633528}],
#      'distance': 1448,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1567531438',
#     'hasPerk': False},
#    {'id': '544cea5d498ecb0abcc86d8d',
#     'name': 'Salt Lounge And Bar',
#     'location': {'lat': 12.970763162519031,
#      'lng': 77.64123759559142,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.970763162519031,
#        'lng': 77.64123759559142}],
#      'distance': 293,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d11e941735',
#       'name': 'Cocktail Bar',
#       'pluralName': 'Cocktail Bars',
#       'shortName': 'Cocktail',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1567531438',
#     'hasPerk': False},
#    {'id': '4d5fb8b15c39b1f7b013fb49',
#     'name': "Shiva's Bar",
#     'location': {'crossStreet': '80 feet road',
#      'lat': 12.972356910251468,
#      'lng': 77.6468909733283,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.972356910251468,
#        'lng': 77.6468909733283}],
#      'distance': 704,
#      'cc': 'IN',
#      'city': 'Bangalore',
#      'state': 'Karnātaka',
#      'country': 'India',
#      'formattedAddress': ['80 feet road', 'Bangalore', 'Karnātaka', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1567531438',
#     'hasPerk': False},
#    {'id': '4bc8edaf762beee16ab63d38',
#     'name': 'The Park Hotel',
#     'location': {'address': '14/7 Mahatma Gandhi Road',
#      'lat': 12.97373919262414,
#      'lng': 77.61976618750536,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.97373919262414,
#        'lng': 77.61976618750536}],
#      'distance': 2246,
#      'cc': 'IN',
#      'city': 'Bangalore',
#      'state': 'Karnātaka',
#      'country': 'India',
#      'formattedAddress': ['14/7 Mahatma Gandhi Road',
#       'Bangalore',
#       'Karnātaka',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1567531438',
#     'hasPerk': False},
#    {'id': '55292209498e816af26fb9d5',
#     'name': 'The Table Blue Cafè Wine Bar',
#     'location': {'address': '100ft Rd, Indiranagar',
#      'lat': 12.976883442770895,
#      'lng': 77.64095792204367,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.976883442770895,
#        'lng': 77.64095792204367}],
#      'distance': 403,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['100ft Rd, Indiranagar', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d123941735',
#       'name': 'Wine Bar',
#       'pluralName': 'Wine Bars',
#       'shortName': 'Wine Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1567531438',
#     'hasPerk': False},
#    {'id': '4d55d7c3cc65a14355c7535e',
#     'name': 'Hotel Transit Living (Serviced Apartments)',
#     'location': {'lat': 12.958713,
#      'lng': 77.644276,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.958713,
#        'lng': 77.644276}],
#      'distance': 1674,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1567531438',
#     'hasPerk': False},
#    {'id': '4c62bb6879d1e21e39c0d615',
#     'name': 'New Punjabi Hotel',
#     'location': {'address': '80 Feet Rd.',
#      'lat': 12.972644841822078,
#      'lng': 77.64683402752696,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.972644841822078,
#        'lng': 77.64683402752696}],
#      'distance': 694,
#      'cc': 'IN',
#      'city': 'Bangalore',
#      'state': 'Karnātaka',
#      'country': 'India',
#      'formattedAddress': ['80 Feet Rd.', 'Bangalore', 'Karnātaka', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1567531438',
#     'hasPerk': False},
#    {'id': '54834faa498eb82fd624a28b',
#     'name': 'Hotel Leela Business Center',
#     'location': {'lat': 12.960978,
#      'lng': 77.648402,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.960978,
#        'lng': 77.648402}],
#      'distance': 1618,
#      'cc': 'IN',
#      'city': 'Bangalore',
#      'state': 'Karnātaka',
#      'country': 'India',
#      'formattedAddress': ['Bangalore', 'Karnātaka', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1567531438',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
venues_df = json_normalize(venues)
venues_df.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d116941735', 'name': 'B...    False
# 1  [{'id': '4bf58dd8d48988d11d941735', 'name': 'S...    False
# 2  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 3  [{'id': '4bf58dd8d48988d116941735', 'name': 'B...    False
# 4  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
#
#                          id  \
# 0  4b8e74edf964a520942333e3
# 1  4b685a68f964a5205a732be3
# 2  4eea06f3b634ea5579ee83a3
# 3  5340596b498e3c13ad5f59a7
# 4  4ba46d04f964a520999c38e3
#
#                                     location.address location.cc  \
# 0                                     322/1 CMH Road          IN
# 1                                        100 Feet Rd          IN
# 2                                   #700 100 Feet Rd          IN
# 3  610, Diagonally Opposite SBI Bank, Near Apple ...          IN
# 4                                    #1, Golf Avenue          IN
#
#   location.city location.country location.crossStreet  location.distance  \
# 0     Bangalore            India          Indiranagar                646
# 1     Bangalore            India          Indiranagar                288
# 2     Bangalore            India                  NaN                375
# 3     Bangalore            India            12th Main                601
# 4     Bangalore            India     HAL Airport Road               1836
#
#                            location.formattedAddress  \
# 0  [322/1 CMH Road (Indiranagar), Bangalore 56003...
# 1  [100 Feet Rd (Indiranagar), Bangalore, Karnāta...
# 2  [#700 100 Feet Rd, Bangalore 560038, Karnātaka...
# 3  [610, Diagonally Opposite SBI Bank, Near Apple...
# 4  [#1, Golf Avenue (HAL Airport Road), Bangalore...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 12.97825344859123...     12.978253
# 1  [{'label': 'display', 'lat': 12.97079487565083...     12.970795
# 2  [{'label': 'display', 'lat': 12.96998317746498...     12.969983
# 3  [{'label': 'display', 'lat': 12.97032868914355...     12.970329
# 4  [{'label': 'display', 'lat': 12.95720848476767...     12.957208
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0     77.637368                   NaN              560038      Karnātaka
# 1     77.641164                   NaN                 NaN      Karnātaka
# 2     77.641146                   NaN              560038      Karnātaka
# 3     77.645107                   NaN                 NaN      Karnātaka
# 4     77.644222                   NaN              560008      Karnātaka
#
#                                 name    referralId venuePage.id
# 0  Hotel Shalimar Bar and Restaurant  v-1567531438          NaN
# 1                  Xtreme Sports Bar  v-1567531438          NaN
# 2                 Escape Hotel & Spa  v-1567531438          NaN
# 3                         Monkey Bar  v-1567531438          NaN
# 4                 Hotel Royal Orchid  v-1567531438          NaN

# %%
venues_df.shape
# Out:
# (30, 19)

# %%
venues_df.columns
# Out:
# Index(['categories', 'hasPerk', 'id', 'location.address', 'location.cc',
#        'location.city', 'location.country', 'location.crossStreet',
#        'location.distance', 'location.formattedAddress',
#        'location.labeledLatLngs', 'location.lat', 'location.lng',
#        'location.neighborhood', 'location.postalCode', 'location.state',
#        'name', 'referralId', 'venuePage.id'],
#       dtype='object')

# %% [markdown]
# There are around 30 venues around Indiranagar. Let us fetch the time when these venues are the most active along with their rating

# %%
# All the venue Ids
venues_df['id']
# Out:
# 0     4b8e74edf964a520942333e3
# 1     4b685a68f964a5205a732be3
# 2     4eea06f3b634ea5579ee83a3
# 3     5340596b498e3c13ad5f59a7
# 4     4ba46d04f964a520999c38e3
# 5     4e0985d8483b98d4171d993c
# 6     5cdace71b399f7002c75331a
# 7     55f317ca498ebbeb5a53d7ab
# 8     5a0477da31ac6c284a78a5b9
# 9     4c62b2dffa7bc928f5ab0e27
# 10    55311431498edd664401629e
# 11    51a61c6e498ec6f690bf2987
# 12    5bcf3d0a31fd14002c6dba07
# 13    4e0a20ed14959022c8a93dec
# 14    4e02e6c6a809d5cf4526a843
# 15    533850ad498e5cc1a990f184
# 16    4bbb52c3cf2fc9b60f6da202
# 17    4b7028aef964a5205f092de3
# 18    4f539056e4b03be36423185e
# 19    50ba05f6e4b013672743c917
# 20    51ceb927498e9830f7d20a93
# 21    55979d94498ef8cc2442fee2
# 22    4f8ed510e4b0e25286acac8f
# 23    544cea5d498ecb0abcc86d8d
# 24    4d5fb8b15c39b1f7b013fb49
# 25    4bc8edaf762beee16ab63d38
# 26    55292209498e816af26fb9d5
# 27    4d55d7c3cc65a14355c7535e
# 28    4c62bb6879d1e21e39c0d615
# 29    54834faa498eb82fd624a28b
# Name: id, dtype: object

# %%
# A list to store the fetched venue rating and popular time and venue id
# Since I am unable to automate the API call to fetch details of all these venues. I am manually fetching data
#          for each lcoation and creating a list 
venue_popularity_rating = []

# %%
temp_id = '4b8e74edf964a520942333e3'
temp_url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(temp_id, CLIENT_ID, CLIENT_SECRET, VERSION) 
temp_deets = requests.get(temp_url).json()
temp_popular=temp_deets['response']['venue']['popular']['timeframes']
temp_rating=temp_deets['response']['venue']['rating']
temp_venue=temp_deets['response']['venue']['id']
print(temp_popular, type(temp_popular))
print('\n')
print(temp_rating, type(temp_rating))
print(temp_venue, type(temp_venue))
venue_popularity_rating.append([temp_venue, temp_rating, temp_popular])
# Out:
# [{'days': 'Today', 'includesToday': True, 'open': [{'renderedTime': '1:00 PM–2:00 PM'}, {'renderedTime': '7:00 PM–11:00 PM'}], 'segments': []}, {'days': 'Wed', 'open': [{'renderedTime': '6:00 PM–Midnight'}], 'segments': []}, {'days': 'Thu', 'open': [{'renderedTime': '1:00 PM–2:00 PM'}, {'renderedTime': '7:00 PM–Midnight'}], 'segments': []}, {'days': 'Fri–Sat', 'open': [{'renderedTime': '7:00 PM–1:00 AM'}], 'segments': []}, {'days': 'Sun', 'open': [{'renderedTime': '8:00 PM–Midnight'}], 'segments': []}, {'days': 'Mon', 'open': [{'renderedTime': '7:00 PM–11:00 PM'}], 'segments': []}] <class 'list'>
#
#
# 7.5 <class 'float'>
# 4b8e74edf964a520942333e3 <class 'str'>

# %%
temp_id_2 = '4b685a68f964a5205a732be3'
temp_url_2 = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(temp_id_2, CLIENT_ID, CLIENT_SECRET, VERSION) 
temp_deets_2 = requests.get(temp_url_2).json()
temp_popular_2=temp_deets_2['response']['venue']['popular']['timeframes']
temp_rating_2=temp_deets_2['response']['venue']['rating']
temp_venue_2=temp_deets_2['response']['venue']['id']
print(temp_popular_2, type(temp_popular_2))
print('\n')
print(temp_rating_2, type(temp_rating_2))
print(temp_venue_2, type(temp_venue_2))
venue_popularity_rating.append([temp_venue_2, temp_rating_2, temp_popular_2])
# Out:
# [{'days': 'Today', 'includesToday': True, 'open': [{'renderedTime': '7:00 PM–11:00 PM'}], 'segments': []}, {'days': 'Wed', 'open': [{'renderedTime': '7:00 PM–Midnight'}], 'segments': []}, {'days': 'Thu', 'open': [{'renderedTime': '7:00 PM–11:00 PM'}], 'segments': []}, {'days': 'Fri', 'open': [{'renderedTime': '6:00 PM–Midnight'}], 'segments': []}, {'days': 'Sat', 'open': [{'renderedTime': '3:00 PM–1:00 AM'}], 'segments': []}, {'days': 'Sun', 'open': [{'renderedTime': '1:00 PM–11:00 PM'}], 'segments': []}, {'days': 'Mon', 'open': [{'renderedTime': '7:00 PM–9:00 PM'}], 'segments': []}] <class 'list'>
#
#
# 6.1 <class 'float'>
# 4b685a68f964a5205a732be3 <class 'str'>

# %%
temp_id_3 = '55311431498edd664401629e'
temp_url_3 = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(temp_id_3, CLIENT_ID, CLIENT_SECRET, VERSION) 
temp_deets_3 = requests.get(temp_url_3).json()
temp_popular_3=temp_deets_3['response']['venue']['popular']['timeframes']
temp_rating_3=temp_deets_3['response']['venue']['rating']
temp_venue_3=temp_deets_3['response']['venue']['id']
print(temp_popular_3, type(temp_popular_3))
print('\n')
print(temp_rating_3, type(temp_rating_3))
print(temp_venue_3, type(temp_venue_3))
venue_popularity_rating.append([temp_venue_3, temp_rating_3, temp_popular_3])
# Out:
# [{'days': 'Today', 'includesToday': True, 'open': [{'renderedTime': '1:00 PM–3:00 PM'}, {'renderedTime': '7:00 PM–11:00 PM'}], 'segments': []}, {'days': 'Wed', 'open': [{'renderedTime': '1:00 PM–3:00 PM'}, {'renderedTime': '7:00 PM–10:00 PM'}], 'segments': []}, {'days': 'Thu', 'open': [{'renderedTime': '2:00 PM–3:00 PM'}, {'renderedTime': '8:00 PM–11:00 PM'}], 'segments': []}, {'days': 'Fri', 'open': [{'renderedTime': '1:00 PM–4:00 PM'}, {'renderedTime': '7:00 PM–Midnight'}], 'segments': []}, {'days': 'Sat', 'open': [{'renderedTime': 'Noon–4:00 PM'}, {'renderedTime': '7:00 PM–11:00 PM'}], 'segments': []}, {'days': 'Sun', 'open': [{'renderedTime': 'Noon–11:00 PM'}], 'segments': []}, {'days': 'Mon', 'open': [{'renderedTime': '1:00 PM–2:00 PM'}, {'renderedTime': '7:00 PM–11:00 PM'}], 'segments': []}] <class 'list'>
#
#
# 7.6 <class 'float'>
# 55311431498edd664401629e <class 'str'>

# %%
temp_id_4 = '5340596b498e3c13ad5f59a7'
temp_url_4 = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(temp_id_4, CLIENT_ID, CLIENT_SECRET, VERSION) 
temp_deets_4 = requests.get(temp_url_4).json()
temp_popular_4=temp_deets_4['response']['venue']['popular']['timeframes']
temp_rating_4=temp_deets_4['response']['venue']['rating']
temp_venue_4=temp_deets_4['response']['venue']['id']
print(temp_popular_4, type(temp_popular_4))
print('\n')
print(temp_rating_4, type(temp_rating_4))
print(temp_venue_4, type(temp_venue_4))
venue_popularity_rating.append([temp_venue_4, temp_rating_4, temp_popular_4])
# Out:
# [{'days': 'Today', 'includesToday': True, 'open': [{'renderedTime': '8:00 PM–11:00 PM'}], 'segments': []}, {'days': 'Wed', 'open': [{'renderedTime': '1:00 PM–2:00 PM'}, {'renderedTime': '7:00 PM–11:00 PM'}], 'segments': []}, {'days': 'Thu', 'open': [{'renderedTime': '8:00 PM–11:00 PM'}], 'segments': []}, {'days': 'Fri', 'open': [{'renderedTime': '1:00 PM–2:00 PM'}, {'renderedTime': '8:00 PM–1:00 AM'}], 'segments': []}, {'days': 'Sat', 'open': [{'renderedTime': '3:00 PM–1:00 AM'}], 'segments': []}, {'days': 'Sun', 'open': [{'renderedTime': '10:00 AM–11:00 PM'}], 'segments': []}, {'days': 'Mon', 'open': [{'renderedTime': '6:00 PM–7:00 PM'}, {'renderedTime': '9:00 PM–10:00 PM'}], 'segments': []}] <class 'list'>
#
#
# 7.4 <class 'float'>
# 5340596b498e3c13ad5f59a7 <class 'str'>

# %%
temp_id_5 = '4e0a20ed14959022c8a93dec'
temp_url_5 = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(temp_id_5, CLIENT_ID, CLIENT_SECRET, VERSION) 
temp_deets_5 = requests.get(temp_url_5).json()
temp_popular_5=temp_deets_5['response']['venue']['popular']['timeframes']
temp_rating_5=temp_deets_5['response']['venue']['rating']
temp_venue_5=temp_deets_5['response']['venue']['id']
print(temp_popular_5, type(temp_popular_5))
print('\n')
print(temp_rating_5, type(temp_rating_5))
print(temp_venue_5, type(temp_venue_5))
venue_popularity_rating.append([temp_venue_5, temp_rating_5, temp_popular_5])
# Out:
# [{'days': 'Today', 'includesToday': True, 'open': [{'renderedTime': '4:00 PM–1:00 AM'}], 'segments': []}, {'days': 'Wed', 'open': [{'renderedTime': '6:00 PM–Midnight'}], 'segments': []}, {'days': 'Thu', 'open': [{'renderedTime': '3:00 PM–Midnight'}], 'segments': []}, {'days': 'Fri–Sat', 'open': [{'renderedTime': '4:00 PM–11:00 PM'}], 'segments': []}, {'days': 'Sun', 'open': [{'renderedTime': '11:00 AM–2:00 PM'}, {'renderedTime': '4:00 PM–11:00 PM'}], 'segments': []}, {'days': 'Mon', 'open': [{'renderedTime': '6:00 PM–Midnight'}], 'segments': []}] <class 'list'>
#
#
# 7.6 <class 'float'>
# 4e0a20ed14959022c8a93dec <class 'str'>

# %%
temp_id_6 = '51a61c6e498ec6f690bf2987'
temp_url_6 = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(temp_id_6, CLIENT_ID, CLIENT_SECRET, VERSION) 
temp_deets_6 = requests.get(temp_url_6).json()
temp_popular_6=temp_deets_6['response']['venue']['popular']['timeframes']
temp_rating_6=temp_deets_6['response']['venue']['rating']
temp_venue_6=temp_deets_6['response']['venue']['id']
print(temp_popular_6, type(temp_popular_6))
print('\n')
print(temp_rating_6, type(temp_rating_6))
print(temp_venue_6, type(temp_venue_6))
venue_popularity_rating.append([temp_venue_6, temp_rating_6, temp_popular_6])
# Out:
# [{'days': 'Today', 'includesToday': True, 'open': [{'renderedTime': '7:00 PM–11:00 PM'}], 'segments': []}, {'days': 'Wed', 'open': [{'renderedTime': '7:00 PM–Midnight'}], 'segments': []}, {'days': 'Thu', 'open': [{'renderedTime': '7:00 PM–11:00 PM'}], 'segments': []}, {'days': 'Fri', 'open': [{'renderedTime': '7:00 PM–1:00 AM'}], 'segments': []}, {'days': 'Sat', 'open': [{'renderedTime': '4:00 PM–1:00 AM'}], 'segments': []}, {'days': 'Sun', 'open': [{'renderedTime': '2:00 PM–11:00 PM'}], 'segments': []}, {'days': 'Mon', 'open': [{'renderedTime': 'None'}], 'segments': []}] <class 'list'>
#
#
# 7.9 <class 'float'>
# 51a61c6e498ec6f690bf2987 <class 'str'>

# %%
temp_id_7 = '533850ad498e5cc1a990f184'
temp_url_7 = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(temp_id_7, CLIENT_ID, CLIENT_SECRET, VERSION) 
temp_deets_7 = requests.get(temp_url_7).json()
temp_popular_7=temp_deets_7['response']['venue']['popular']['timeframes']
temp_rating_7=temp_deets_7['response']['venue']['rating']
temp_venue_7=temp_deets_7['response']['venue']['id']
print(temp_popular_7, type(temp_popular_7))
print('\n')
print(temp_rating_7, type(temp_rating_7))
print(temp_venue_7, type(temp_venue_7))
venue_popularity_rating.append([temp_venue_7, temp_rating_7, temp_popular_7])
# Out:
# [{'days': 'Today', 'includesToday': True, 'open': [{'renderedTime': '8:00 PM–11:00 PM'}], 'segments': []}, {'days': 'Wed', 'open': [{'renderedTime': '1:00 PM–2:00 PM'}, {'renderedTime': '7:00 PM–11:00 PM'}], 'segments': []}, {'days': 'Thu', 'open': [{'renderedTime': '6:00 PM–11:00 PM'}], 'segments': []}, {'days': 'Fri', 'open': [{'renderedTime': '1:00 PM–2:00 PM'}, {'renderedTime': '6:00 PM–1:00 AM'}], 'segments': []}, {'days': 'Sat', 'open': [{'renderedTime': '1:00 PM–1:00 AM'}], 'segments': []}, {'days': 'Sun', 'open': [{'renderedTime': '10:00 AM–11:00 PM'}], 'segments': []}, {'days': 'Mon', 'open': [{'renderedTime': '8:00 PM–11:00 PM'}], 'segments': []}] <class 'list'>
#
#
# 8.4 <class 'float'>
# 533850ad498e5cc1a990f184 <class 'str'>

# %%
temp_id_8 = '4bcafd09511f95211f9ab0c7'
temp_url_8 = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(temp_id_8, CLIENT_ID, CLIENT_SECRET, VERSION) 
temp_deets_8 = requests.get(temp_url_8).json()
temp_popular_8=temp_deets_8['response']['venue']['popular']['timeframes']
temp_rating_8=temp_deets_8['response']['venue']['rating']
temp_venue_8=temp_deets_8['response']['venue']['id']
print(temp_popular_8, type(temp_popular_8))
print('\n')
print(temp_rating_8, type(temp_rating_8))
print(temp_venue_8, type(temp_venue_8))
venue_popularity_rating.append([temp_venue_8, temp_rating_8, temp_popular_8])
# Out:
# [{'days': 'Today', 'includesToday': True, 'open': [{'renderedTime': '4:00 PM–10:00 PM'}], 'segments': []}, {'days': 'Wed', 'open': [{'renderedTime': '4:00 PM–10:00 PM'}], 'segments': []}, {'days': 'Thu', 'open': [{'renderedTime': '2:00 PM–Midnight'}], 'segments': []}, {'days': 'Fri', 'open': [{'renderedTime': 'Noon–Midnight'}], 'segments': []}, {'days': 'Sat', 'open': [{'renderedTime': '2:00 PM–Midnight'}], 'segments': []}, {'days': 'Sun', 'open': [{'renderedTime': '9:00 AM–10:00 AM'}, {'renderedTime': '1:00 PM–11:00 PM'}], 'segments': []}, {'days': 'Mon', 'open': [{'renderedTime': '6:00 PM–10:00 PM'}], 'segments': []}] <class 'list'>
#
#
# 5.7 <class 'float'>
# 4bcafd09511f95211f9ab0c7 <class 'str'>

# %%
temp_id_9 = '4c62b2dffa7bc928f5ab0e27'
temp_url_9 = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(temp_id_9, CLIENT_ID, CLIENT_SECRET, VERSION) 
temp_deets_9 = requests.get(temp_url_9).json()
temp_popular_9=temp_deets_9['response']['venue']['popular']['timeframes']
temp_rating_9=temp_deets_9['response']['venue']['rating']
temp_venue_9=temp_deets_9['response']['venue']['id']
print(temp_popular_9, type(temp_popular_9))
print('\n')
print(temp_rating_9, type(temp_rating_9))
print(temp_venue_9, type(temp_venue_9))
venue_popularity_rating.append([temp_venue_9, temp_rating_9, temp_popular_9])
# Out:
# [{'days': 'Today', 'includesToday': True, 'open': [{'renderedTime': '1:00 PM–2:00 PM'}, {'renderedTime': '7:00 PM–11:00 PM'}], 'segments': []}, {'days': 'Wed', 'open': [{'renderedTime': '1:00 PM–2:00 PM'}, {'renderedTime': '7:00 PM–11:00 PM'}], 'segments': []}, {'days': 'Thu', 'open': [{'renderedTime': '9:00 AM–10:00 AM'}, {'renderedTime': '7:00 PM–Midnight'}], 'segments': []}, {'days': 'Fri', 'open': [{'renderedTime': '1:00 PM–3:00 PM'}, {'renderedTime': '6:00 PM–Midnight'}], 'segments': []}, {'days': 'Sat', 'open': [{'renderedTime': '2:00 PM–4:00 PM'}, {'renderedTime': '7:00 PM–11:00 PM'}], 'segments': []}, {'days': 'Sun', 'open': [{'renderedTime': '7:00 PM–11:00 PM'}], 'segments': []}, {'days': 'Mon', 'open': [{'renderedTime': '7:00 PM–11:00 PM'}], 'segments': []}] <class 'list'>
#
#
# 8.0 <class 'float'>
# 4c62b2dffa7bc928f5ab0e27 <class 'str'>

# %%
temp_id_10 = '50ba05f6e4b013672743c917'
temp_url_10 = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(temp_id_10, CLIENT_ID, CLIENT_SECRET, VERSION) 
temp_deets_10 = requests.get(temp_url_10).json()
temp_popular_10=temp_deets_10['response']['venue']['popular']['timeframes']
temp_rating_10=temp_deets_10['response']['venue']['rating']
temp_venue_10=temp_deets_10['response']['venue']['id']
print(temp_popular_10, type(temp_popular_10))
print('\n')
print(temp_rating_10, type(temp_rating_10))
print(temp_venue_10, type(temp_venue_10))
venue_popularity_rating.append([temp_venue_10, temp_rating_10, temp_popular_10])
# Out:
# [{'days': 'Today', 'includesToday': True, 'open': [{'renderedTime': '1:00 PM–2:00 PM'}, {'renderedTime': '5:00 PM–7:00 PM'}, {'renderedTime': '9:00 PM–Midnight'}], 'segments': []}, {'days': 'Wed', 'open': [{'renderedTime': '4:00 PM–5:00 PM'}, {'renderedTime': '7:00 PM–1:00 AM'}], 'segments': []}, {'days': 'Thu', 'open': [{'renderedTime': '2:00 PM–3:00 PM'}, {'renderedTime': '9:00 PM–Midnight'}], 'segments': []}, {'days': 'Fri', 'open': [{'renderedTime': '6:00 PM–2:00 AM'}], 'segments': []}, {'days': 'Sat', 'open': [{'renderedTime': '11:00 AM–1:00 AM'}], 'segments': []}, {'days': 'Sun', 'open': [{'renderedTime': '1:00 PM–1:00 AM'}], 'segments': []}, {'days': 'Mon', 'open': [{'renderedTime': '1:00 PM–4:00 PM'}, {'renderedTime': '8:00 PM–Midnight'}], 'segments': []}] <class 'list'>
#
#
# 5.5 <class 'float'>
# 50ba05f6e4b013672743c917 <class 'str'>

# %%
# code to automate the Foursquare API call to get rating and popularity
# does not work in sandbox/free subrscription
# venue_popularity_rating = []
# for temp_id in venues_df:
#     temp_url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(temp_id, CLIENT_ID, CLIENT_SECRET, VERSION)
#     temp_deets = requests.get(temp_url).json()
#     temp_popular = temp_deets['response']['venue']['popular']['timeframes']
#     temp_rating = temp_deets['response']['venue']['rating']
#     temp_venue = temp_deets['response']['venue']['id']
#     print(temp_popular)
#     print('\n')
#     print(temp_rating)
#     venue_popularity_rating.append(temp_venue,temp_rating, temp_popular)
# print(len(venue_popularity_rating))

# %%
# I could fetch details of only about 10 lcoations 
print(len(venue_popularity_rating))
# Out:
# 10

# %%
# Convert the details fetched into a pandas data frame for further processing
df_venue_popularity_rating = pd.DataFrame(venue_popularity_rating)
df_venue_popularity_rating.columns = ['id', 'rating', 'popularity']
df_venue_popularity_rating.head()
# Out:
#                          id  rating  \
# 0  4b8e74edf964a520942333e3     7.5
# 1  4b685a68f964a5205a732be3     6.1
# 2  55311431498edd664401629e     7.6
# 3  5340596b498e3c13ad5f59a7     7.4
# 4  4e0a20ed14959022c8a93dec     7.6
#
#                                           popularity
# 0  [{'days': 'Today', 'includesToday': True, 'ope...
# 1  [{'days': 'Today', 'includesToday': True, 'ope...
# 2  [{'days': 'Today', 'includesToday': True, 'ope...
# 3  [{'days': 'Today', 'includesToday': True, 'ope...
# 4  [{'days': 'Today', 'includesToday': True, 'ope...

# %%
# Merge the venue details along with its rating and popularity
merge_df = venues_df.merge(df_venue_popularity_rating,
    how='left',
    left_on='id',
    right_on='id',
    sort=False,
    suffixes=('_x', '_y'),
    copy=True,
    indicator=False,
    validate=None,)
merge_df.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d116941735', 'name': 'B...    False
# 1  [{'id': '4bf58dd8d48988d11d941735', 'name': 'S...    False
# 2  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 3  [{'id': '4bf58dd8d48988d116941735', 'name': 'B...    False
# 4  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
#
#                          id  \
# 0  4b8e74edf964a520942333e3
# 1  4b685a68f964a5205a732be3
# 2  4eea06f3b634ea5579ee83a3
# 3  5340596b498e3c13ad5f59a7
# 4  4ba46d04f964a520999c38e3
#
#                                     location.address location.cc  \
# 0                                     322/1 CMH Road          IN
# 1                                        100 Feet Rd          IN
# 2                                   #700 100 Feet Rd          IN
# 3  610, Diagonally Opposite SBI Bank, Near Apple ...          IN
# 4                                    #1, Golf Avenue          IN
#
#   location.city location.country location.crossStreet  location.distance  \
# 0     Bangalore            India          Indiranagar                646
# 1     Bangalore            India          Indiranagar                288
# 2     Bangalore            India                  NaN                375
# 3     Bangalore            India            12th Main                601
# 4     Bangalore            India     HAL Airport Road               1836
#
#                            location.formattedAddress  ... location.lat  \
# 0  [322/1 CMH Road (Indiranagar), Bangalore 56003...  ...    12.978253
# 1  [100 Feet Rd (Indiranagar), Bangalore, Karnāta...  ...    12.970795
# 2  [#700 100 Feet Rd, Bangalore 560038, Karnātaka...  ...    12.969983
# 3  [610, Diagonally Opposite SBI Bank, Near Apple...  ...    12.970329
# 4  [#1, Golf Avenue (HAL Airport Road), Bangalore...  ...    12.957208
#
#    location.lng  location.neighborhood location.postalCode location.state  \
# 0     77.637368                    NaN              560038      Karnātaka
# 1     77.641164                    NaN                 NaN      Karnātaka
# 2     77.641146                    NaN              560038      Karnātaka
# 3     77.645107                    NaN                 NaN      Karnātaka
# 4     77.644222                    NaN              560008      Karnātaka
#
#                                 name    referralId venuePage.id rating  \
# 0  Hotel Shalimar Bar and Restaurant  v-1567531438          NaN    7.5
# 1                  Xtreme Sports Bar  v-1567531438          NaN    6.1
# 2                 Escape Hotel & Spa  v-1567531438          NaN    NaN
# 3                         Monkey Bar  v-1567531438          NaN    7.4
# 4                 Hotel Royal Orchid  v-1567531438          NaN    NaN
#
#                                           popularity
# 0  [{'days': 'Today', 'includesToday': True, 'ope...
# 1  [{'days': 'Today', 'includesToday': True, 'ope...
# 2                                                NaN
# 3  [{'days': 'Today', 'includesToday': True, 'ope...
# 4                                                NaN
#
# [5 rows x 21 columns]

# %%
merge_df.shape
# Out:
# (30, 21)

# %% [markdown]
# Out of the 30 venues selected venues in Indiranagar only few venues have populartity/rating data. Let us now look at
# these venues on a map

# %% [markdown]
# First let us visualize the venues that have a rating and popular time data

# %%
import folium
# create map of Indiranagr using latitude and longitude values
map_indiranagar = folium.Map(location=[latitude, longitude], zoom_start=14)

# add markers to map
for lat, lng, label in zip(merge_df.loc[merge_df['rating'].notnull(),'location.lat'], 
                           merge_df.loc[merge_df['rating'].notnull(),'location.lng'], 
                          merge_df.loc[merge_df['rating'].notnull(),'name']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_indiranagar)  
    
map_indiranagar
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Let us plot the venues that do not have much data about popular timing and/or ratings

# %%
# add markers to map
for lat, lng, label in zip(merge_df.loc[merge_df['rating'].isnull(),'location.lat'], 
                           merge_df.loc[merge_df['rating'].isnull(),'location.lng'], 
                          merge_df.loc[merge_df['rating'].isnull(),'name']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=3,
        popup=label,
        color='red',
        fill=True,
        fill_color='#FF0000',
        fill_opacity=0.7,
        parse_html=False).add_to(map_indiranagar)  
    
map_indiranagar
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# As can be seen many of the venues do not have data about popular timings or rating. these could be because of the following reasons
# * Foursquare API is not yet popular with all the visitors or folks in Bangalore
# * The venues are not that popular/happening

# %% [markdown]
# Let us explore fruther to understnad better. Let us look at the rated venues and see their categories

# %%
#Let us check the top rated venues
merge_df['rating'].sort_values().value_counts()
# Out:
# 7.6    2
# 7.4    1
# 6.1    1
# 7.9    1
# 8.4    1
# 8.0    1
# 7.5    1
# 5.5    1
# Name: rating, dtype: int64

# %%
# Let us highlight the venues with rating > 7 with a black ring
# add markers to map
for lat, lng, label in zip(merge_df.loc[(merge_df['rating'].notnull()) & (merge_df['rating']>7) ,'location.lat'], 
                           merge_df.loc[(merge_df['rating'].notnull()) & (merge_df['rating']>7) ,'location.lng'], 
                          merge_df.loc[(merge_df['rating'].notnull()) & (merge_df['rating']>7) ,'name']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=3,
        popup=label,
        color='black',
        fill=True,
        fill_color='#FF0000',
        fill_opacity=0.7,
        parse_html=False).add_to(map_indiranagar)  
    
map_indiranagar
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Listing the venues with rating greater than 7
varx = merge_df.loc[(merge_df['rating'].notnull()) & (merge_df['rating']>7) ,['name', 'categories','rating']]
varx
# Out:
#                                       name  \
# 0        Hotel Shalimar Bar and Restaurant
# 3                               Monkey Bar
# 9                         Retro Lounge Bar
# 10           Chianti Ristorante & Wine Bar
# 11  The Humming Tree - Music Venue and Bar
# 13                             Library Bar
# 15                              Monkey Bar
#
#                                            categories  rating
# 0   [{'id': '4bf58dd8d48988d116941735', 'name': 'B...     7.5
# 3   [{'id': '4bf58dd8d48988d116941735', 'name': 'B...     7.4
# 9   [{'id': '4bf58dd8d48988d116941735', 'name': 'B...     8.0
# 10  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...     7.6
# 11  [{'id': '4bf58dd8d48988d1e5931735', 'name': 'M...     7.9
# 13  [{'id': '4bf58dd8d48988d116941735', 'name': 'B...     7.6
# 15  [{'id': '4bf58dd8d48988d11b941735', 'name': 'P...     8.4

# %%
# Let us get the categories column cleaned. Thankfully there is code already available from Week 2 lesson :-P
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
merge_df['categories'] = merge_df.apply(get_category_type, axis=1)
merge_df.head()
# Out:
#    categories  hasPerk                        id  \
# 0         Bar    False  4b8e74edf964a520942333e3
# 1  Sports Bar    False  4b685a68f964a5205a732be3
# 2       Hotel    False  4eea06f3b634ea5579ee83a3
# 3         Bar    False  5340596b498e3c13ad5f59a7
# 4       Hotel    False  4ba46d04f964a520999c38e3
#
#                                     location.address location.cc  \
# 0                                     322/1 CMH Road          IN
# 1                                        100 Feet Rd          IN
# 2                                   #700 100 Feet Rd          IN
# 3  610, Diagonally Opposite SBI Bank, Near Apple ...          IN
# 4                                    #1, Golf Avenue          IN
#
#   location.city location.country location.crossStreet  location.distance  \
# 0     Bangalore            India          Indiranagar                646
# 1     Bangalore            India          Indiranagar                288
# 2     Bangalore            India                  NaN                375
# 3     Bangalore            India            12th Main                601
# 4     Bangalore            India     HAL Airport Road               1836
#
#                            location.formattedAddress  ... location.lat  \
# 0  [322/1 CMH Road (Indiranagar), Bangalore 56003...  ...    12.978253
# 1  [100 Feet Rd (Indiranagar), Bangalore, Karnāta...  ...    12.970795
# 2  [#700 100 Feet Rd, Bangalore 560038, Karnātaka...  ...    12.969983
# 3  [610, Diagonally Opposite SBI Bank, Near Apple...  ...    12.970329
# 4  [#1, Golf Avenue (HAL Airport Road), Bangalore...  ...    12.957208
#
#    location.lng  location.neighborhood location.postalCode location.state  \
# 0     77.637368                    NaN              560038      Karnātaka
# 1     77.641164                    NaN                 NaN      Karnātaka
# 2     77.641146                    NaN              560038      Karnātaka
# 3     77.645107                    NaN                 NaN      Karnātaka
# 4     77.644222                    NaN              560008      Karnātaka
#
#                                 name    referralId venuePage.id rating  \
# 0  Hotel Shalimar Bar and Restaurant  v-1567531438          NaN    7.5
# 1                  Xtreme Sports Bar  v-1567531438          NaN    6.1
# 2                 Escape Hotel & Spa  v-1567531438          NaN    NaN
# 3                         Monkey Bar  v-1567531438          NaN    7.4
# 4                 Hotel Royal Orchid  v-1567531438          NaN    NaN
#
#                                           popularity
# 0  [{'days': 'Today', 'includesToday': True, 'ope...
# 1  [{'days': 'Today', 'includesToday': True, 'ope...
# 2                                                NaN
# 3  [{'days': 'Today', 'includesToday': True, 'ope...
# 4                                                NaN
#
# [5 rows x 21 columns]

# %%
# Now that category column is cleaned let us analyse the venues with rating greater than 7
merge_df.loc[(merge_df['rating'].notnull()) & (merge_df['rating']>7) ,['categories','name','rating']]
# Out:
#             categories                                    name  rating
# 0                  Bar       Hotel Shalimar Bar and Restaurant     7.5
# 3                  Bar                              Monkey Bar     7.4
# 9                  Bar                        Retro Lounge Bar     8.0
# 10  Italian Restaurant           Chianti Ristorante & Wine Bar     7.6
# 11         Music Venue  The Humming Tree - Music Venue and Bar     7.9
# 13                 Bar                             Library Bar     7.6
# 15                 Pub                              Monkey Bar     8.4

# %% [markdown]
# Interseting, most of the venues seems to be top of the line bars with the only exception being an Italian resturant.

# %% [markdown]
# I serached Google for more information about the other venues. It appears that most of the venues are food and family kinda places. Few of the venues are also local bars where the local working class poulation would like to visit, these venues usually do not have music or good ambience to relax/party. The working class population are not usually tech savy and may not use applications like Foursquare hence we do not have much information about these venues.

# %% [markdown]
# ### From the above visuals, searches and analysis we can infer that folks in Bangalore would like to party where there is alcohol serverd along with music and a good ambience. Most of these venues seems to be centered around 'Sony Center Signal'.
